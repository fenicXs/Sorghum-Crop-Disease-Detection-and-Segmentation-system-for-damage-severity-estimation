# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="kX1T67tvKBnWqTL6ql1I")
project = rf.workspace("phoenix-jsc7c").project("test-gzrpx")
version = project.version(3)
dataset = version.download("yolov12")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.58-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.1.31)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.1.0)
# Collecting pillow-heif>=0.18.0 (from roboflow)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.1)
# Downloading roboflow-1.1.58-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 6.0 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.0 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 42.3 MB/s eta 0:00:00
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 107.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: filetype, python-dotenv, pillow-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 python-dotenv-1.0.1 roboflow-1.1.58
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in test-3 to yolov12:: 100%|██████████| 59474/59474 [00:05<00:00, 11482.22it/s]
# Extracting Dataset Version Zip to test-3 in yolov12:: 100%|██████████| 1568/1568 [00:00<00:00, 6095.66it/s]

# %%
# !nvidia-smi
# Out:
# Thu Mar 20 07:58:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   36C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ### Install dependencies
#
# **NOTE:** Currently, YOLOv12 does not have its own PyPI package, so we install it directly from GitHub while also adding roboflow (to conveniently pull datasets from the Roboflow Universe), supervision (to visualize inference results and benchmark the model’s performance), and flash-attn (to accelerate attention-based computations via optimized CUDA kernels).

# %%
# !pip install -q git+https://github.com/sunsmarterjie/yolov12.git roboflow supervision flash-attn
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 108.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.2 MB/s eta 0:00:00
#   Building wheel for ultralytics (pyproject.toml) ... done
#   Building wheel for flash-attn (setup.py) ... done

# %% [markdown]
# ## Fine-tune YOLOv12 model
#
# We are now ready to fine-tune our YOLOv12 model. In the code below, we initialize the model using a starting checkpoint—here, we use `yolov12s.yaml`, but you can replace it with any other model (e.g., `yolov12n.pt`, `yolov12m.pt`, `yolov12l.pt`, or `yolov12x.pt`) based on your preference. We set the training to run for 100 epochs in this example; however, you should adjust the number of epochs along with other hyperparameters such as batch size, image size, and augmentation settings (scale, mosaic, mixup, and copy-paste) based on your hardware capabilities and dataset size.
#
# **Note:** **Note that after training, you might encounter a `TypeError: argument of type 'PosixPath' is not iterable error` — this is a known issue, but your model weights will still be saved, so you can safely proceed to running inference.**

# %%
from ultralytics import YOLO

model = YOLO('yolov12m.yaml')

results = model.train(data=f'{dataset.location}/data.yaml', epochs=20)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/yolov12/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# New https://pypi.org/project/ultralytics/8.3.93 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# engine/trainer: task=detect, mode=train, model=yolov12m.yaml, data=/content/test-3/data.yaml, epochs=20, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.1, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/yolov12/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 133MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     37120  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2, 1, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    147968  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2, 1, 4]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2664960  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2664960  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLOv12m summary: 533 layers, 19,609,875 parameters, 19,609,859 gradients, 60.1 GFLOPs
#
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/sunsmarterjie/yolov12/releases/download/turbo/yolov12n.pt to 'yolov12n.pt'...
# 100%|██████████| 5.26M/5.26M [00:00<00:00, 53.7MB/s]
# AMP: checks passed ✅
# train: Scanning /content/test-3/train/labels... 609 images, 0 backgrounds, 0 corrupt: 100%|██████████| 609/609 [00:00<00:00, 1497.55it/s]
# train: New cache created: /content/test-3/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 208, len(boxes) = 864. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# Argument(s) 'quality_lower' are not valid for transform ImageCompression
# val: Scanning /content/test-3/valid/labels... 113 images, 0 backgrounds, 0 corrupt: 100%|██████████| 113/113 [00:00<00:00, 1307.35it/s]
# val: New cache created: /content/test-3/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 35, len(boxes) = 148. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 131 weight(decay=0.0), 138 weight(decay=0.0005), 137 bias(decay=0.0)
# TensorBoard: WARNING ⚠️ TensorBoard graph visualization failure Tracing failed sanity checks!
# ERROR: Graphs differed across invocations!
# 	Graph diff:
# 		  graph(%self.1 : __torch__.ultralytics.nn.tasks.DetectionModel,
# 		        %x.1 : Tensor):
# 		    %model : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_21 : __torch__.ultralytics.nn.modules.head.Detect = prim::GetAttr[name="21"](%model)
# 		    %model.43 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_20 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="20"](%model.43)
# 		    %model.41 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_19 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="19"](%model.41)
# 		    %model.39 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_18 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="18"](%model.39)
# 		    %model.37 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_17 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="17"](%model.37)
# 		    %model.35 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_16 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="16"](%model.35)
# 		    %model.33 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_15 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="15"](%model.33)
# 		    %model.31 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_14 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="14"](%model.31)
# 		    %model.29 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_13 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="13"](%model.29)
# 		    %model.27 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_12 : __torch__.torch.nn.modules.upsampling.Upsample = prim::GetAttr[name="12"](%model.27)
# 		    %model.25 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_11 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="11"](%model.25)
# 		    %model.23 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_10 : __torch__.ultralytics.nn.modules.conv.Concat = prim::GetAttr[name="10"](%model.23)
# 		    %model.21 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_9 : __torch__.torch.nn.modules.upsampling.Upsample = prim::GetAttr[name="9"](%model.21)
# 		    %model.19 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_8 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="8"](%model.19)
# 		    %model.17 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="7"](%model.17)
# 		    %model.15 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_6 : __torch__.ultralytics.nn.modules.block.A2C2f = prim::GetAttr[name="6"](%model.15)
# 		    %model.13 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="5"](%model.13)
# 		    %model.11 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_4 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="4"](%model.11)
# 		    %model.9 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="3"](%model.9)
# 		    %model.7 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_2.3 : __torch__.ultralytics.nn.modules.block.C3k2 = prim::GetAttr[name="2"](%model.7)
# 		    %model.5 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_1.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="1"](%model.5)
# 		    %model.3 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_21.1 : __torch__.ultralytics.nn.modules.head.Detect = prim::GetAttr[name="21"](%model.3)
# 		    %cv3.1 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="cv3"](%_21.1)
# 		    %_2.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="2"](%cv3.1)
# 		    %_1.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="1"](%_2.1)
# 		    %_1.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="1"](%_1.1)
# 		    %act.1 : __torch__.torch.nn.modules.activation.SiLU = prim::GetAttr[name="act"](%_1.3)
# 		    %model.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="model"](%self.1)
# 		    %_0.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="0"](%model.1)
# 		    %75 : int = prim::Constant[value=2](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %76 : int = prim::Constant[value=1](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %77 : bool = prim::Constant[value=0](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %78 : int = prim::Constant[value=0](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %79 : bool = prim::Constant[value=1](), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %conv.1 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_0.1)
# 		    %bias.275 : Tensor = prim::GetAttr[name="bias"](%conv.1)
# 		    %weight.277 : Tensor = prim::GetAttr[name="weight"](%conv.1)
# 		    %83 : int[] = prim::ListConstruct(%75, %75), scope: __module.model.0/__module.model.0.conv
# 		    %84 : int[] = prim::ListConstruct(%76, %76), scope: __module.model.0/__module.model.0.conv
# 		    %85 : int[] = prim::ListConstruct(%76, %76), scope: __module.model.0/__module.model.0.conv
# 		    %86 : int[] = prim::ListConstruct(%78, %78), scope: __module.model.0/__module.model.0.conv
# 		    %input.1 : Tensor = aten::_convolution(%x.1, %weight.277, %bias.275, %83, %84, %85, %77, %86, %76, %77, %79, %79, %79), scope: __module.model.0/__module.model.0.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.3 : Tensor = aten::silu_(%input.1), scope: __module.model.0/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %89 : int = prim::Constant[value=2](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %90 : int = prim::Constant[value=1](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %91 : bool = prim::Constant[value=0](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %92 : int = prim::Constant[value=0](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %93 : bool = prim::Constant[value=1](), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %conv.3 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_1.5)
# 		    %bias.277 : Tensor = prim::GetAttr[name="bias"](%conv.3)
# 		    %weight.279 : Tensor = prim::GetAttr[name="weight"](%conv.3)
# 		    %97 : int[] = prim::ListConstruct(%89, %89), scope: __module.model.1/__module.model.1.conv
# 		    %98 : int[] = prim::ListConstruct(%90, %90), scope: __module.model.1/__module.model.1.conv
# 		    %99 : int[] = prim::ListConstruct(%90, %90), scope: __module.model.1/__module.model.1.conv
# 		    %100 : int[] = prim::ListConstruct(%92, %92), scope: __module.model.1/__module.model.1.conv
# 		    %input.5 : Tensor = aten::_convolution(%input.3, %weight.279, %bias.277, %97, %98, %99, %91, %100, %89, %91, %93, %93, %93), scope: __module.model.1/__module.model.1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.7 : Tensor = aten::silu_(%input.5), scope: __module.model.1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %103 : int = prim::Constant[value=2](), scope: __module.model.2 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:238:0
# 		    %104 : bool = prim::Constant[value=1](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %105 : bool = prim::Constant[value=0](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %106 : int = prim::Constant[value=0](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %107 : int = prim::Constant[value=1](), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %cv2.7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_2.3)
# 		    %m.3 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_2.3)
# 		    %_0.5 : __torch__.ultralytics.nn.modules.block.C3k = prim::GetAttr[name="0"](%m.3)
# 		    %cv1.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_2.3)
# 		    %conv.5 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.1)
# 		    %bias.279 : Tensor = prim::GetAttr[name="bias"](%conv.5)
# 		    %weight.281 : Tensor = prim::GetAttr[name="weight"](%conv.5)
# 		    %115 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %116 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %117 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %118 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv
# 		    %input.9 : Tensor = aten::_convolution(%input.7, %weight.281, %bias.279, %115, %116, %117, %105, %118, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.cv1/__module.model.2.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %120 : Tensor = aten::silu_(%input.9), scope: __module.model.2/__module.model.2.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %121 : Tensor[] = aten::chunk(%120, %103, %107), scope: __module.model.2 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:238:0
# 		    %122 : Tensor, %input.11 : Tensor = prim::ListUnpack(%121), scope: __module.model.2
# 		    %cv3.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv3"](%_0.5)
# 		    %cv2.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.5)
# 		    %m.1 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="m"](%_0.5)
# 		    %cv1.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.5)
# 		    %conv.7 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.3)
# 		    %bias.281 : Tensor = prim::GetAttr[name="bias"](%conv.7)
# 		    %weight.283 : Tensor = prim::GetAttr[name="weight"](%conv.7)
# 		    %131 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %132 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %133 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %134 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv
# 		    %input.13 : Tensor = aten::_convolution(%input.11, %weight.283, %bias.281, %131, %132, %133, %105, %134, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.2.m.0.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.15 : Tensor = aten::silu_(%input.13), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %_1.7 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="1"](%m.1)
# 		    %_0.3 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="0"](%m.1)
# 		    %cv2.1 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.3)
# 		    %cv1.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.3)
# 		    %conv.9 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.5)
# 		    %bias.283 : Tensor = prim::GetAttr[name="bias"](%conv.9)
# 		    %weight.285 : Tensor = prim::GetAttr[name="weight"](%conv.9)
# 		    %144 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %145 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %146 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %147 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv
# 		    %input.17 : Tensor = aten::_convolution(%input.15, %weight.285, %bias.283, %144, %145, %146, %105, %147, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.2.m.0.m.0.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.19 : Tensor = aten::silu_(%input.17), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %conv.11 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.1)
# 		    %bias.285 : Tensor = prim::GetAttr[name="bias"](%conv.11)
# 		    %weight.287 : Tensor = prim::GetAttr[name="weight"](%conv.11)
# 		    %153 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %154 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %155 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %156 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv
# 		    %input.21 : Tensor = aten::_convolution(%input.19, %weight.287, %bias.285, %153, %154, %155, %105, %156, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.2.m.0.m.0.cv2.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %158 : Tensor = aten::silu_(%input.21), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0/__module.model.2.m.0.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %input.23 : Tensor = aten::add(%input.15, %158, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.0 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:348:0
# 		    %cv2.3 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_1.7)
# 		    %cv1.7 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_1.7)
# 		    %conv.13 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.7)
# 		    %bias.287 : Tensor = prim::GetAttr[name="bias"](%conv.13)
# 		    %weight.289 : Tensor = prim::GetAttr[name="weight"](%conv.13)
# 		    %165 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %166 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %167 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %168 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv
# 		    %input.25 : Tensor = aten::_convolution(%input.23, %weight.289, %bias.287, %165, %166, %167, %105, %168, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.2.m.0.m.1.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.27 : Tensor = aten::silu_(%input.25), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %conv.15 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.3)
# 		    %bias.289 : Tensor = prim::GetAttr[name="bias"](%conv.15)
# 		    %weight.291 : Tensor = prim::GetAttr[name="weight"](%conv.15)
# 		    %174 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %175 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %176 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %177 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv
# 		    %input.29 : Tensor = aten::_convolution(%input.27, %weight.291, %bias.289, %174, %175, %176, %105, %177, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.2.m.0.m.1.cv2.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %179 : Tensor = aten::silu_(%input.29), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1/__module.model.2.m.0.m.1.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %180 : Tensor = aten::add(%input.23, %179, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.m/__module.model.2.m.0.m.1 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:348:0
# 		    %conv.17 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.5)
# 		    %bias.291 : Tensor = prim::GetAttr[name="bias"](%conv.17)
# 		    %weight.293 : Tensor = prim::GetAttr[name="weight"](%conv.17)
# 		    %184 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %185 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %186 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %187 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv
# 		    %input.31 : Tensor = aten::_convolution(%input.11, %weight.293, %bias.291, %184, %185, %186, %105, %187, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.2.m.0.cv2.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %189 : Tensor = aten::silu_(%input.31), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %190 : Tensor[] = prim::ListConstruct(%180, %189), scope: __module.model.2/__module.model.2.m.0
# 		    %input.33 : Tensor = aten::cat(%190, %107), scope: __module.model.2/__module.model.2.m.0 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:264:0
# 		    %conv.19 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv3.3)
# 		    %bias.293 : Tensor = prim::GetAttr[name="bias"](%conv.19)
# 		    %weight.295 : Tensor = prim::GetAttr[name="weight"](%conv.19)
# 		    %195 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %196 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %197 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %198 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv
# 		    %input.35 : Tensor = aten::_convolution(%input.33, %weight.295, %bias.293, %195, %196, %197, %105, %198, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.2.m.0.cv3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %200 : Tensor = aten::silu_(%input.35), scope: __module.model.2/__module.model.2.m.0/__module.model.2.m.0.cv3/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %201 : Tensor[] = prim::ListConstruct(%122, %input.11, %200), scope: __module.model.2
# 		    %input.37 : Tensor = aten::cat(%201, %107), scope: __module.model.2 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:240:0
# 		    %conv.21 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.7)
# 		    %bias.295 : Tensor = prim::GetAttr[name="bias"](%conv.21)
# 		    %weight.297 : Tensor = prim::GetAttr[name="weight"](%conv.21)
# 		    %206 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %207 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %208 : int[] = prim::ListConstruct(%107, %107), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %209 : int[] = prim::ListConstruct(%106, %106), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv
# 		    %input.39 : Tensor = aten::_convolution(%input.37, %weight.297, %bias.295, %206, %207, %208, %105, %209, %107, %105, %104, %104, %104), scope: __module.model.2/__module.model.2.cv2/__module.model.2.cv2.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.41 : Tensor = aten::silu_(%input.39), scope: __module.model.2/__module.model.2.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %212 : int = prim::Constant[value=2](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %213 : int = prim::Constant[value=1](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %214 : bool = prim::Constant[value=0](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %215 : int = prim::Constant[value=0](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %216 : int = prim::Constant[value=4](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %217 : bool = prim::Constant[value=1](), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %conv.23 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%_3)
# 		    %bias.297 : Tensor = prim::GetAttr[name="bias"](%conv.23)
# 		    %weight.299 : Tensor = prim::GetAttr[name="weight"](%conv.23)
# 		    %221 : int[] = prim::ListConstruct(%212, %212), scope: __module.model.3/__module.model.3.conv
# 		    %222 : int[] = prim::ListConstruct(%213, %213), scope: __module.model.3/__module.model.3.conv
# 		    %223 : int[] = prim::ListConstruct(%213, %213), scope: __module.model.3/__module.model.3.conv
# 		    %224 : int[] = prim::ListConstruct(%215, %215), scope: __module.model.3/__module.model.3.conv
# 		    %input.43 : Tensor = aten::_convolution(%input.41, %weight.299, %bias.297, %221, %222, %223, %214, %224, %216, %214, %217, %217, %217), scope: __module.model.3/__module.model.3.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.45 : Tensor = aten::silu_(%input.43), scope: __module.model.3/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %227 : int = prim::Constant[value=2](), scope: __module.model.4 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:238:0
# 		    %228 : bool = prim::Constant[value=1](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %229 : bool = prim::Constant[value=0](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %230 : int = prim::Constant[value=0](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %231 : int = prim::Constant[value=1](), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %cv2.15 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_4)
# 		    %m.7 : __torch__.torch.nn.modules.container.ModuleList = prim::GetAttr[name="m"](%_4)
# 		    %_0.9 : __torch__.ultralytics.nn.modules.block.C3k = prim::GetAttr[name="0"](%m.7)
# 		    %cv1.9 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_4)
# 		    %conv.25 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.9)
# 		    %bias.299 : Tensor = prim::GetAttr[name="bias"](%conv.25)
# 		    %weight.301 : Tensor = prim::GetAttr[name="weight"](%conv.25)
# 		    %239 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %240 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %241 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %242 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv
# 		    %input.47 : Tensor = aten::_convolution(%input.45, %weight.301, %bias.299, %239, %240, %241, %229, %242, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.cv1/__module.model.4.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %244 : Tensor = aten::silu_(%input.47), scope: __module.model.4/__module.model.4.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %245 : Tensor[] = aten::chunk(%244, %227, %231), scope: __module.model.4 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:238:0
# 		    %246 : Tensor, %input.49 : Tensor = prim::ListUnpack(%245), scope: __module.model.4
# 		    %cv3.5 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv3"](%_0.9)
# 		    %cv2.13 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.9)
# 		    %m.5 : __torch__.torch.nn.modules.container.Sequential = prim::GetAttr[name="m"](%_0.9)
# 		    %cv1.11 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.9)
# 		    %conv.27 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.11)
# 		    %bias.301 : Tensor = prim::GetAttr[name="bias"](%conv.27)
# 		    %weight.303 : Tensor = prim::GetAttr[name="weight"](%conv.27)
# 		    %255 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %256 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %257 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %258 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv
# 		    %input.51 : Tensor = aten::_convolution(%input.49, %weight.303, %bias.301, %255, %256, %257, %229, %258, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.4.m.0.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.53 : Tensor = aten::silu_(%input.51), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %_1.9 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="1"](%m.5)
# 		    %_0.7 : __torch__.ultralytics.nn.modules.block.Bottleneck = prim::GetAttr[name="0"](%m.5)
# 		    %cv2.9 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_0.7)
# 		    %cv1.13 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_0.7)
# 		    %conv.29 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.13)
# 		    %bias.303 : Tensor = prim::GetAttr[name="bias"](%conv.29)
# 		    %weight.305 : Tensor = prim::GetAttr[name="weight"](%conv.29)
# 		    %268 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %269 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %270 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %271 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv
# 		    %input.55 : Tensor = aten::_convolution(%input.53, %weight.305, %bias.303, %268, %269, %270, %229, %271, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.4.m.0.m.0.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.57 : Tensor = aten::silu_(%input.55), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %conv.31 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.9)
# 		    %bias.305 : Tensor = prim::GetAttr[name="bias"](%conv.31)
# 		    %weight.307 : Tensor = prim::GetAttr[name="weight"](%conv.31)
# 		    %277 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %278 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %279 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %280 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv
# 		    %input.59 : Tensor = aten::_convolution(%input.57, %weight.307, %bias.305, %277, %278, %279, %229, %280, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.4.m.0.m.0.cv2.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %282 : Tensor = aten::silu_(%input.59), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0/__module.model.4.m.0.m.0.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %input.61 : Tensor = aten::add(%input.53, %282, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.0 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:348:0
# 		    %cv2.11 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv2"](%_1.9)
# 		    %cv1.15 : __torch__.ultralytics.nn.modules.conv.Conv = prim::GetAttr[name="cv1"](%_1.9)
# 		    %conv.33 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv1.15)
# 		    %bias.307 : Tensor = prim::GetAttr[name="bias"](%conv.33)
# 		    %weight.309 : Tensor = prim::GetAttr[name="weight"](%conv.33)
# 		    %289 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %290 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %291 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %292 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv
# 		    %input.63 : Tensor = aten::_convolution(%input.61, %weight.309, %bias.307, %289, %290, %291, %229, %292, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.4.m.0.m.1.cv1.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %input.65 : Tensor = aten::silu_(%input.63), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv1/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %conv.35 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.11)
# 		    %bias.309 : Tensor = prim::GetAttr[name="bias"](%conv.35)
# 		    %weight.311 : Tensor = prim::GetAttr[name="weight"](%conv.35)
# 		    %298 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %299 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %300 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %301 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv
# 		    %input.67 : Tensor = aten::_convolution(%input.65, %weight.311, %bias.309, %298, %299, %300, %229, %301, %231, %229, %228, %228, %228), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.4.m.0.m.1.cv2.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %303 : Tensor = aten::silu_(%input.67), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1/__module.model.4.m.0.m.1.cv2/__module.model.21.cv3.2.1.1.act # /usr/local/lib/python3.11/dist-packages/torch/nn/functional.py:2379:0
# 		    %304 : Tensor = aten::add(%input.61, %303, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.m/__module.model.4.m.0.m.1 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:348:0
# 		    %conv.37 : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%cv2.13)
# 		    %bias.311 : Tensor = prim::GetAttr[name="bias"](%conv.37)
# 		    %weight.313 : Tensor = prim::GetAttr[name="weight"](%conv.37)
# 		    %308 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %309 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %310 : int[] = prim::ListConstruct(%231, %231), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# 		    %311 : int[] = prim::ListConstruct(%230, %230), scope: __module.model.4/__module.model.4.m.0/__module.model.4.m.0.cv2/__module.model.4.m.0.cv2.conv
# ...
# 		    %2065 : int = aten::size(%xi.1, %1810), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:103:0
# 		    %2066 : int[] = prim::ListConstruct(%2065, %1805, %1804), scope: __module.model.21
# 		    %2067 : Tensor = aten::view(%xi.1, %2066), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:104:0
# 		    %2068 : int[] = prim::ListConstruct(%2065, %1805, %1804), scope: __module.model.21
# 		    %2069 : Tensor = aten::view(%xi.3, %2068), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:104:0
# 		    %2070 : int[] = prim::ListConstruct(%2065, %1805, %1804), scope: __module.model.21
# 		    %2071 : Tensor = aten::view(%xi, %2070), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:104:0
# 		    %2072 : Tensor[] = prim::ListConstruct(%2067, %2069, %2071), scope: __module.model.21
# 		    %2073 : Tensor = aten::cat(%2072, %1803), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:104:0
# 		    %2074 : int[] = prim::ListConstruct(%1802, %1808), scope: __module.model.21
# 		    %2075 : Tensor[] = aten::split_with_sizes(%2073, %2074, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/torch/_tensor.py:1028:0
# 		    %x : Tensor, %cls : Tensor = prim::ListUnpack(%2075), scope: __module.model.21
# 		    %conv : __torch__.torch.nn.modules.conv.Conv2d = prim::GetAttr[name="conv"](%dfl)
# 		    %2079 : int = aten::size(%x, %1810), scope: __module.model.21/__module.model.21.dfl # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:73:0
# 		    %2080 : int = aten::size(%x, %1803), scope: __module.model.21/__module.model.21.dfl # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:73:0
# 		    %2081 : int[] = prim::ListConstruct(%2079, %1799, %1800, %2080), scope: __module.model.21/__module.model.21.dfl
# 		    %2082 : Tensor = aten::view(%x, %2081), scope: __module.model.21/__module.model.21.dfl # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:74:0
# 		    %2083 : Tensor = aten::transpose(%2082, %1803, %1808), scope: __module.model.21/__module.model.21.dfl # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:74:0
# 		    %input : Tensor = aten::softmax(%2083, %1808, %1801), scope: __module.model.21/__module.model.21.dfl # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:74:0
# 		    %weight : Tensor = prim::GetAttr[name="weight"](%conv)
# 		    %2086 : int[] = prim::ListConstruct(%1808, %1808), scope: __module.model.21/__module.model.21.dfl/__module.model.21.dfl.conv
# 		    %2087 : int[] = prim::ListConstruct(%1810, %1810), scope: __module.model.21/__module.model.21.dfl/__module.model.21.dfl.conv
# 		    %2088 : int[] = prim::ListConstruct(%1808, %1808), scope: __module.model.21/__module.model.21.dfl/__module.model.21.dfl.conv
# 		    %2089 : int[] = prim::ListConstruct(%1810, %1810), scope: __module.model.21/__module.model.21.dfl/__module.model.21.dfl.conv
# 		    %2090 : Tensor = aten::_convolution(%input, %weight, %1801, %2086, %2087, %2088, %1809, %2089, %1808, %1809, %1811, %1811, %1811), scope: __module.model.21/__module.model.21.dfl/__module.model.21.dfl.conv # /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:549:0
# 		    %2091 : int[] = prim::ListConstruct(%2079, %1799, %2080), scope: __module.model.21/__module.model.21.dfl
# 		    %distance : Tensor = aten::view(%2090, %2091), scope: __module.model.21/__module.model.21.dfl # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/block.py:74:0
# 		    %anchor_points : Tensor = aten::unsqueeze(%1798, %1810), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:129:0
# 		    %2094 : Tensor[] = aten::chunk(%distance, %1803, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py:350:0
# 		    %lt : Tensor, %rb : Tensor = prim::ListUnpack(%2094), scope: __module.model.21
# 		    %x1y1 : Tensor = aten::sub(%anchor_points, %lt, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py:351:0
# 		    %x2y2 : Tensor = aten::add(%anchor_points, %rb, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py:352:0
# 		    %2099 : Tensor = aten::add(%x1y1, %x2y2, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py:354:0
# 		    %c_xy : Tensor = aten::div(%2099, %1797), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py:354:0
# 		    %wh : Tensor = aten::sub(%x2y2, %x1y1, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py:355:0
# 		    %2102 : Tensor[] = prim::ListConstruct(%c_xy, %wh), scope: __module.model.21
# 		    %2103 : Tensor = aten::cat(%2102, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py:356:0
# 		    %dbox : Tensor = aten::mul(%2103, %1796), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:129:0
# 		    %2105 : Tensor = aten::sigmoid(%cls), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:131:0
# 		    %2106 : Tensor[] = prim::ListConstruct(%dbox, %2105), scope: __module.model.21
# 		    %2107 : Tensor = aten::cat(%2106, %1808), scope: __module.model.21 # /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py:131:0
# 		    return (%2107)
# 	First diverging operator:
# 	Node diff:
# 		- %model : __torch__.torch.nn.modules.container.___torch_mangle_1717.Sequential = prim::GetAttr[name="model"](%self.1)
# 		?                                                               ^^^^
# 		+ %model : __torch__.torch.nn.modules.container.___torch_mangle_2209.Sequential = prim::GetAttr[name="model"](%self.1)
# 		?                                                               ^^^^
#
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      9.43G      3.439      3.501      4.204          2        640: 100%|██████████| 39/39 [00:16<00:00,  2.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<00:00,  1.99it/s]
#                    all        113        148    0.00248      0.568    0.00826    0.00223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      9.38G      3.106      3.161      3.861          4        640: 100%|██████████| 39/39 [00:14<00:00,  2.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.30it/s]
#                    all        113        148    0.00277      0.635     0.0137    0.00467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      9.36G       2.79      2.945      3.451          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.01it/s]
#                    all        113        148    0.00587     0.0743     0.0026   0.000684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      9.35G      2.588      2.778      3.191          4        640: 100%|██████████| 39/39 [00:14<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.32it/s]
#                    all        113        148     0.0634      0.426     0.0395     0.0126
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      9.34G      2.472      2.679      3.019          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.26it/s]
#                    all        113        148      0.048       0.48     0.0343     0.0119
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      9.32G      2.506      2.559      2.945          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.35it/s]
#                    all        113        148      0.236      0.351      0.186     0.0622
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      9.39G      2.407      2.493      2.876          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.37it/s]
#                    all        113        148      0.367      0.459      0.305      0.106
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      9.32G      2.345      2.379      2.782          3        640: 100%|██████████| 39/39 [00:14<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.36it/s]
#                    all        113        148       0.44      0.493      0.449      0.199
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      9.34G      2.233      2.312      2.689          1        640: 100%|██████████| 39/39 [00:14<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.31it/s]
#                    all        113        148      0.521      0.558      0.489      0.208
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      9.33G      2.206       2.21      2.647          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.37it/s]
#                    all        113        148      0.538      0.466      0.498      0.201
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# Argument(s) 'quality_lower' are not valid for transform ImageCompression
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      9.37G      2.023       2.03      2.616          9        640: 100%|██████████| 39/39 [00:14<00:00,  2.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.32it/s]
#                    all        113        148      0.522      0.676        0.6       0.32
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      9.32G       1.89      1.661      2.522          1        640: 100%|██████████| 39/39 [00:14<00:00,  2.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.38it/s]
#                    all        113        148      0.598      0.662       0.64      0.327
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      9.36G      1.894      1.606      2.488          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.39it/s]
#                    all        113        148      0.633      0.652      0.654      0.372
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      9.32G      1.867      1.554      2.445          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.37it/s]
#                    all        113        148      0.713      0.653      0.682      0.399
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      9.36G      1.774      1.441      2.332          1        640: 100%|██████████| 39/39 [00:14<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.35it/s]
#                    all        113        148      0.846      0.696      0.755      0.456
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      9.32G      1.708      1.353      2.299          2        640: 100%|██████████| 39/39 [00:14<00:00,  2.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.38it/s]
#                    all        113        148      0.831      0.764      0.791      0.508
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      9.34G      1.661      1.392      2.255          4        640: 100%|██████████| 39/39 [00:14<00:00,  2.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.34it/s]
#                    all        113        148      0.919       0.73      0.803      0.518
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      9.31G      1.545      1.221      2.143          1        640: 100%|██████████| 39/39 [00:14<00:00,  2.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.35it/s]
#                    all        113        148      0.894      0.764      0.809      0.521
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      9.36G      1.508      1.198      2.149          1        640: 100%|██████████| 39/39 [00:14<00:00,  2.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.35it/s]
#                    all        113        148      0.846       0.78      0.797      0.539
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      9.32G      1.423      1.123      2.074          1        640: 100%|██████████| 39/39 [00:14<00:00,  2.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  3.35it/s]
#                    all        113        148      0.906      0.784      0.813      0.559
# 20 epochs completed in 0.099 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 39.7MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 39.7MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.63 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# YOLOv12m summary (fused): 402 layers, 19,577,299 parameters, 0 gradients, 59.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
#                    all        113        148      0.906      0.784      0.813      0.558
# Speed: 0.2ms preprocess, 7.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/train

# %% [markdown]
# ## Evaluate fine-tuned YOLOv12 model

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					   R_curve.png	       val_batch0_labels.jpg
# confusion_matrix_normalized.png			   results.csv	       val_batch0_pred.jpg
# confusion_matrix.png				   results.png	       val_batch1_labels.jpg
# events.out.tfevents.1742457653.e9fb7a967d45.450.0  train_batch0.jpg    val_batch1_pred.jpg
# F1_curve.png					   train_batch1.jpg    val_batch2_labels.jpg
# labels_correlogram.jpg				   train_batch2.jpg    val_batch2_pred.jpg
# labels.jpg					   train_batch390.jpg  weights
# P_curve.png					   train_batch391.jpg
# PR_curve.png					   train_batch392.jpg

# %%
from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=1000)

# %%
from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train/results.png', width=1000)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=1200)

# %%
import supervision as sv

ds = sv.DetectionDataset.from_yolo(
    images_directory_path=f"{dataset.location}/test/images",
    annotations_directory_path=f"{dataset.location}/test/labels",
    data_yaml_path=f"{dataset.location}/data.yaml"
)

ds.classes
# Out:
# ['Rust']

# %%
from supervision.metrics import MeanAveragePrecision

model = YOLO(f'/{HOME}/runs/detect/train/weights/best.pt')

predictions = []
targets = []

for _, image, target in ds:
    results = model(image, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results)

    predictions.append(detections)
    targets.append(target)

map = MeanAveragePrecision().update(predictions, targets).compute()

# %%
print("mAP 50:95", map.map50_95)
print("mAP 50", map.map50)
print("mAP 75", map.map75)
# Out:
# mAP 50:95 0.5779505923700998
# mAP 50 0.8524403822891506
# mAP 75 0.6465396655152451

# %%
map.plot()

# %% [markdown]
# ## Run inference with fine-tuned YOLOv12 model

# %%
import supervision as sv

model = YOLO(f'/{HOME}/runs/detect/train/weights/best.pt')

ds = sv.DetectionDataset.from_yolo(
    images_directory_path=f"{dataset.location}/test/images",
    annotations_directory_path=f"{dataset.location}/test/labels",
    data_yaml_path=f"{dataset.location}/data.yaml"
)

# %%
import random

i = random.randint(0, len(ds))

image_path, image, target = ds[i]

results = model(image, verbose=False)[0]
detections = sv.Detections.from_ultralytics(results).with_nms()

box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

annotated_image = image.copy()
annotated_image = box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
