# %%
# !pip install -U segmentation-models-pytorch -q

# %%
from google.colab.patches import cv2_imshow

# %%
import os
import cv2
import sys
import glob
import shutil
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import albumentations as A
from dataclasses import dataclass
from tqdm import tqdm,trange,tqdm_notebook
from albumentations.pytorch import ToTensorV2
import segmentation_models_pytorch as smp
from segmentation_models_pytorch import utils

import torch, torchvision
import torch.nn as nn
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torchvision.models as models
import torch.nn.functional as F
import torch.optim as optim

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

# %%
@dataclass

class Config:
    maxsize: int = 224
    batch_size: int = 64
    lr: float = 1e-4

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ### **LOAD DATASET**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
celeb_path = '/content/drive/MyDrive/Sorghum Disease Image Dataset/Rust'
segment_path = '/content/drive/MyDrive/Rust_mask'

def get_images(img_path, mask_path):
    img_files = os.listdir(img_path)
    mask_files = os.listdir(mask_path)

    img_names = {os.path.splitext(f)[0] for f in img_files}
    mask_names = {os.path.splitext(f)[0] for f in mask_files}

    matching_names = img_names.intersection(mask_names)
    matching_pairs = []
    print(matching_names)
    for name in matching_names:
        img_file = os.path.join(img_path, name + '.jpg')
        mask_file = os.path.join(mask_path, name + '.png')
        if os.path.exists(img_file) and os.path.exists(mask_file):
            matching_pairs.append((img_file, mask_file))
    return matching_pairs

# %%
img_paths = get_images(celeb_path, segment_path)

img_fold = []
mask_fold = []

for i, m in img_paths:
    img_fold.append(i)
    mask_fold.append(m)
# Out:
# {'Rust300', 'Rust1794', 'Rust2343', 'Rust404', 'Rust1820', 'Rust609', 'Rust662', 'Rust2245', 'Rust1677', 'Rust502', 'Rust448', 'Rust1818', 'Rust8', 'Rust1634', 'Rust1511', 'Rust431', 'Rust2210', 'Rust210', 'Rust2115', 'Rust1688', 'Rust569', 'Rust79', 'Rust2204', 'Rust319', 'Rust1461', 'Rust465', 'Rust803', 'Rust1838', 'Rust1306', 'Rust391', 'Rust2053', 'Rust1539', 'Rust1003', 'Rust1812', 'Rust1836', 'Rust202', 'Rust422', 'Rust659', 'Rust1412', 'Rust2240', 'Rust1073', 'Rust1083', 'Rust1703', 'Rust1056', 'Rust1715', 'Rust1351', 'Rust190', 'Rust539', 'Rust593', 'Rust2127', 'Rust370', 'Rust566', 'Rust740', 'Rust1272', 'Rust2312', 'Rust1778', 'Rust550', 'Rust561', 'Rust595', 'Rust718', 'Rust1398', 'Rust1028', 'Rust1320', 'Rust1604', 'Rust440', 'Rust1780', 'Rust1996', 'Rust826', 'Rust1968', 'Rust608', 'Rust487', 'Rust2218', 'Rust2035', 'Rust1633', 'Rust1129', 'Rust1348', 'Rust152', 'Rust1763', 'Rust2185', 'Rust393', 'Rust2316', 'Rust1067', 'Rust213', 'Rust1411', 'Rust580', 'Rust1038', 'Rust1082', 'Rust1584', 'Rust1088', 'Rust1640', 'Rust778', 'Rust1344', 'Rust317', 'Rust166', 'Rust376', 'Rust1068', 'Rust1793', 'Rust1924', 'Rust676', 'Rust1853', 'Rust1366', 'Rust626', 'Rust74', 'Rust1069', 'Rust1151', 'Rust552', 'Rust752', 'Rust2253', 'Rust1700', 'Rust2075', 'Rust705', 'Rust1869', 'Rust62', 'Rust1551', 'Rust1713', 'Rust19', 'Rust1659', 'Rust182', 'Rust1014', 'Rust1089', 'Rust1005', 'Rust784', 'Rust1323', 'Rust1297', 'Rust1748', 'Rust2299', 'Rust2257', 'Rust594', 'Rust651', 'Rust1179', 'Rust809', 'Rust2176', 'Rust369', 'Rust2194', 'Rust2067', 'Rust1294', 'Rust1784', 'Rust1166', 'Rust1341', 'Rust719', 'Rust66', 'Rust1552', 'Rust113', 'Rust1240', 'Rust572', 'Rust1491', 'Rust1122', 'Rust2325', 'Rust1041', 'Rust1185', 'Rust1712', 'Rust817', 'Rust1790', 'Rust360', 'Rust1035', 'Rust107', 'Rust1051', 'Rust183', 'Rust433', 'Rust1526', 'Rust1682', 'Rust2364', 'Rust1211', 'Rust2198', 'Rust1394', 'Rust1931', 'Rust522', 'Rust327', 'Rust579', 'Rust1123', 'Rust2095', 'Rust1957', 'Rust1215', 'Rust1408', 'Rust1664', 'Rust1171', 'Rust1782', 'Rust1039', 'Rust1208', 'Rust1125', 'Rust2069', 'Rust2269', 'Rust731', 'Rust1388', 'Rust1543', 'Rust1942', 'Rust2136', 'Rust1362', 'Rust1646', 'Rust2333', 'Rust1471', 'Rust1830', 'Rust248', 'Rust1148', 'Rust1132', 'Rust2118', 'Rust1896', 'Rust497', 'Rust1932', 'Rust667', 'Rust1658', 'Rust2104', 'Rust1929', 'Rust1618', 'Rust1086', 'Rust292', 'Rust418', 'Rust23', 'Rust1518', 'Rust2339', 'Rust432', 'Rust1766', 'Rust412', 'Rust1879', 'Rust2145', 'Rust2188', 'Rust1414', 'Rust1305', 'Rust394', 'Rust2137', 'Rust1200', 'Rust192', 'Rust1585', 'Rust1333', 'Rust2041', 'Rust1775', 'Rust2004', 'Rust2085', 'Rust1216', 'Rust1475', 'Rust1927', 'Rust425', 'Rust1487', 'Rust1811', 'Rust707', 'Rust1418', 'Rust1578', 'Rust1621', 'Rust2187', 'Rust211', 'Rust2318', 'Rust1765', 'Rust1465', 'Rust2368', 'Rust450', 'Rust528', 'Rust1684', 'Rust1025', 'Rust1989', 'Rust1828', 'Rust2233', 'Rust519', 'Rust53', 'Rust825', 'Rust679', 'Rust2192', 'Rust1007', 'Rust1155', 'Rust599', 'Rust64', 'Rust139', 'Rust1385', 'Rust2092', 'Rust2287', 'Rust765', 'Rust1642', 'Rust2313', 'Rust2234', 'Rust59', 'Rust356', 'Rust1143', 'Rust2221', 'Rust160', 'Rust2282', 'Rust2157', 'Rust196', 'Rust615', 'Rust813', 'Rust510', 'Rust1046', 'Rust35', 'Rust1581', 'Rust1167', 'Rust1900', 'Rust815', 'Rust1631', 'Rust1342', 'Rust2370', 'Rust793', 'Rust106', 'Rust1440', 'Rust2082', 'Rust1943', 'Rust52', 'Rust1945', 'Rust132', 'Rust2201', 'Rust1779', 'Rust2108', 'Rust1649', 'Rust117', 'Rust1998', 'Rust2093', 'Rust786', 'Rust1799', 'Rust1281', 'Rust1234', 'Rust554', 'Rust1372', 'Rust504', 'Rust606', 'Rust374', 'Rust1113', 'Rust1223', 'Rust2054', 'Rust2356', 'Rust1239', 'Rust2180', 'Rust380', 'Rust754', 'Rust527', 'Rust1400', 'Rust451', 'Rust1416', 'Rust1373', 'Rust1773', 'Rust406', 'Rust728', 'Rust1823', 'Rust1192', 'Rust1609', 'Rust1263', 'Rust1241', 'Rust1368', 'Rust222', 'Rust820', 'Rust1402', 'Rust1184', 'Rust1717', 'Rust712', 'Rust1255', 'Rust283', 'Rust1889', 'Rust408', 'Rus ...

# %% [markdown]
# ### **PREPROCESS**

# %%
data_transform = A.Compose([
    A.HorizontalFlip(p=0.3),
    A.Resize(256,256),
    A.OneOf(
        [
            A.Sharpen(alpha = (0.1, 0.2), lightness = (0.1, 0.2), p = 0.3),
            A.Blur(blur_limit = [1,3], p=0.3),
            A.GaussNoise(var_limit = (1,5), p = 0.3)
        ]
    ),
    A.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# %%
test_transform = A.Compose([
    A.Resize(256,256),
    A.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# %%
class Dataset(Dataset):
    def __init__(self, img_paths, mask_paths, input_transform = None):

        self.img_paths = img_paths
        self.mask_paths = mask_paths
        self.transform = input_transform

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        mask_path = self.mask_paths[idx]

        image = Image.open(img_path).convert('RGB')
        mask = Image.open(mask_path).convert('L')

        mask = np.array(mask)
        binary_mask = np.where(mask == 255, 1, 0)

        if self.transform:
            augmented = self.transform(image=np.array(image), mask = binary_mask)
            image = augmented['image']
            mask = augmented['mask']

        return image, mask.unsqueeze(0)

# %%
dataset = Dataset(img_fold, mask_fold, input_transform=data_transform)

# %%
dataset

# %%
def visualize_samples(dataset, num_samples=5):
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=num_samples, shuffle=True)
    images, masks = next(iter(dataloader))


    images = images.numpy()
    if images.shape[1] == 3:

        images = images.transpose(0, 2, 3, 1)
    elif images.shape[1] == 1:
        images = images.squeeze(1)

    masks = masks.numpy()
    masks = masks.squeeze(1)


    plt.figure(figsize=(15, 8))
    for idx in range(num_samples):
        plt.subplot(2, num_samples, idx + 1)
        plt.imshow(images[idx])
        plt.axis('off')
        plt.title('Image')

        plt.subplot(2, num_samples, idx + 1 + num_samples)
        plt.imshow(masks[idx], cmap='gray')
        plt.axis('off')
        plt.title('Mask')

    plt.tight_layout()
    plt.show()


visualize_samples(dataset, num_samples=10)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
dataloader = DataLoader(dataset, batch_size = Config.batch_size, pin_memory=True, drop_last=True)

# %% [markdown]
# ### **LOAD MODEL**

# %%
model = smp.Unet(
    encoder_name = 'resnet34',
    encoder_weights = 'imagenet',
    activation = 'sigmoid',
    classes = 1,
    in_channels = 3
)

# %%
model = smp.Unet(
    encoder_name='resnet34',
    encoder_weights=None,
    activation='sigmoid',
    classes=1,
    in_channels=3
)

# %%
criterion = utils.losses.DiceLoss()
optimizer = optim.AdamW(model.parameters(), lr = Config.lr)

metrics = [
    utils.metrics.Fscore(),
    utils.metrics.IoU()
]

# %%
train_epoch = utils.train.TrainEpoch(
    model,
    loss=criterion,
    metrics = metrics,
    optimizer=optimizer,
    device=device,
    verbose=True
)

# %% [markdown]
# ### **TRAINING**

# %%
max_score = 0
num_epochs = 10

loss_logs = {"Loss": []}
metric_logs = {"Metrics": []}

for i in range(num_epochs):
    print('\nEpoch: {}'.format(i))
    train_logs = train_epoch.run(dataloader)
    train_loss, train_metric, train_metric_IOU = list(train_logs.values())
    loss_logs["Loss"].append(train_loss)
    metric_logs["Metrics"].append(train_metric_IOU)

    print('Train - Epoch {}, Loss: {:.4f}, IOU: {:.4f}'.format(i, train_loss, train_metric_IOU))

    if train_metric_IOU > max_score:
        max_score = train_metric_IOU
        torch.save(model.state_dict(), '/content/drive/MyDrive/UNet model/best_model2.pth')
# Out:
# Epoch: 0
# train: 100%|██████████| 34/34 [13:05<00:00, 23.09s/it, dice_loss - 0.5912, fscore - 0.4934, iou_score - 0.3316]
# Train - Epoch 0, Loss: 0.5912, IOU: 0.3316
#
# Epoch: 1
# train: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, dice_loss - 0.4767, fscore - 0.6305, iou_score - 0.462]
# Train - Epoch 1, Loss: 0.4767, IOU: 0.4620
#
# Epoch: 2
# train: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it, dice_loss - 0.4205, fscore - 0.6891, iou_score - 0.5271]
# Train - Epoch 2, Loss: 0.4205, IOU: 0.5271
#
# Epoch: 3
# train: 100%|██████████| 34/34 [01:19<00:00,  2.33s/it, dice_loss - 0.3871, fscore - 0.7163, iou_score - 0.5592]
# Train - Epoch 3, Loss: 0.3871, IOU: 0.5592
#
# Epoch: 4
# train: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, dice_loss - 0.3606, fscore - 0.736, iou_score - 0.5833]
# Train - Epoch 4, Loss: 0.3606, IOU: 0.5833
#
# Epoch: 5
# train: 100%|██████████| 34/34 [01:20<00:00,  2.38s/it, dice_loss - 0.3387, fscore - 0.751, iou_score - 0.6022]
# Train - Epoch 5, Loss: 0.3387, IOU: 0.6022
#
# Epoch: 6
# train: 100%|██████████| 34/34 [01:21<00:00,  2.38s/it, dice_loss - 0.3198, fscore - 0.763, iou_score - 0.6178]
# Train - Epoch 6, Loss: 0.3198, IOU: 0.6178
#
# Epoch: 7
# train: 100%|██████████| 34/34 [01:20<00:00,  2.36s/it, dice_loss - 0.304, fscore - 0.772, iou_score - 0.6295]
# Train - Epoch 7, Loss: 0.3040, IOU: 0.6295
#
# Epoch: 8
# train: 100%|██████████| 34/34 [01:19<00:00,  2.34s/it, dice_loss - 0.2895, fscore - 0.7801, iou_score - 0.6403]
# Train - Epoch 8, Loss: 0.2895, IOU: 0.6403
#
# Epoch: 9
# train: 100%|██████████| 34/34 [01:19<00:00,  2.35s/it, dice_loss - 0.2762, fscore - 0.788, iou_score - 0.6509]
# Train - Epoch 9, Loss: 0.2762, IOU: 0.6509

# %%
def denormalize(image):
    mean_tensor = torch.tensor(mean, device=image.device).view(1, 3, 1, 1)
    std_tensor = torch.tensor(std, device=image.device).view(1, 3, 1, 1)
    return image * std_tensor + mean_tensor

# %%
def visualize_predictions(image, mask, prediction):
    image = denormalize(image).squeeze(0)

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    axes[0].imshow(image.permute(1, 2, 0).cpu().numpy())
    axes[0].set_title('Image')

    axes[1].imshow(mask.squeeze(0).cpu().numpy(), cmap='gray')
    axes[1].set_title('Ground Truth Mask')

    axes[2].imshow(prediction.squeeze(0).cpu().numpy(), cmap='gray')
    axes[2].set_title('Predicted Mask')

    for ax in axes:
        ax.axis('off')

    plt.tight_layout()
    plt.show()

# %%
# model.load_state_dict(torch.load('/kaggle/input/facebest/facebest.pth'))
# model.to(device)
# model.eval()

# %%
for images, masks in dataloader:
    images = images.to(device)
    masks = masks.to(device)

    with torch.no_grad():
        predictions = model(images)
        predictions = (predictions > 0.5).float()

    visualize_predictions(images[62], masks[62], predictions[62])
    break

# %% [markdown]
# ### **TESTING**

# %%
def generation(image_path, model):
    image = Image.open(image_path).convert('RGB')
    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ])
    input_tensor = transform(image).unsqueeze(0)
    model.eval()
    device = next(model.parameters()).device
    input_tensor = input_tensor.to(device)

    with torch.no_grad():
        predictions = model(input_tensor)
        predictions = (predictions > 0.5).float()

    input_image = denormalize(input_tensor).squeeze(0).permute(1, 2, 0).cpu().numpy()
    predicted_mask = predictions.squeeze(0).squeeze(0).cpu().numpy()

    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    axes[0].imshow(input_image)
    axes[0].set_title('Input Image')
    axes[0].axis('off')

    axes[1].imshow(predicted_mask, cmap='gray')
    axes[1].set_title('Predicted Mask')
    axes[1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
test_img_path = '/content/jowar.jpg'

# %%
generation(test_img_path, model)

# %%
test2 = "/content/Rust1.jpg"
generation(test2, model)

# %%
test3 = "/content/Rust2263.jpg"
generation(test3, model)
